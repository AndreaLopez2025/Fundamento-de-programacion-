# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreaLopez2025/Fundamento-de-programacion-/blob/main/Untitled28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#listas (mutable)
arr=[1,2,3]
arr[0]= 10
arr.append(4)
print("lista modificada:",arr)
#tupla (inmutable)
tup=(1,2,3)
try:
  tup[0]=0
except TypeError:
  print("no se puede modificar una tupla")
# Out:
# lista modificada: [10, 2, 3, 4]
# no se puede modificar una tupla
