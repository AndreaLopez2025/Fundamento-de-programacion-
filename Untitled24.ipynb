# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreaLopez2025/Fundamento-de-programacion-/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#numeros pares y suma
suma=0
for i in range(2,21,2):
  print(i)
  print("suma de pares", suma)
# Out:
# 2
# suma de pares 0
# 4
# suma de pares 0
# 6
# suma de pares 0
# 8
# suma de pares 0
# 10
# suma de pares 0
# 12
# suma de pares 0
# 14
# suma de pares 0
# 16
# suma de pares 0
# 18
# suma de pares 0
# 20
# suma de pares 0
