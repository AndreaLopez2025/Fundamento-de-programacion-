# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreaLopez2025/Fundamento-de-programacion-/blob/main/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#leer datos
x = float(input("ingrese x:"))

if x > 0:
  print("x es mayor que cero")
elif x == 0:
  print("x es igual a cero")
else:
  print("x es menor que cero")
# Out:
# ingrese x:10
# x es mayor que cero
