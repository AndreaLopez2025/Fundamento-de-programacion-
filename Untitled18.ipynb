# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreaLopez2025/Fundamento-de-programacion-/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#leer datos
b = float(input('ingrese valor base: '))
a = float(input('ingrese valor de altura: '))
#hacer operacion
area = b * a / 2
perimetro = 3 * b
#print
print("Area:", area)
print("Perimetro:", perimetro)
# Out:
# ingrese valor base: 10
# ingrese valor de altura: 15
# Area: 75.0
# Perimetro: 30.0
