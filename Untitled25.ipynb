# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreaLopez2025/Fundamento-de-programacion-/blob/main/Untitled25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#promedio de n-1 numeros
n=10
suma= sum(range(1,n))
promedio= suma/(n-1)
print("el promedio de 10")
# Out:
# el promedio de 10
